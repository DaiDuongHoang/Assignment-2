# %%
import pandas as pd

# %%
data = pd.read_csv("data/fire.csv")
df = pd.DataFrame(data)

# %%
df
# Out:
#        latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0       -18.411    145.322       334.8   1.3    1.1  2020-01-01        50
# 1       -18.420    145.308       346.6   1.3    1.1  2020-01-01        50
# 2       -18.422    145.321       340.9   1.3    1.1  2020-01-01        50
# 3       -18.438    145.281       338.1   1.3    1.1  2020-01-01        50
# 4       -18.439    145.293       331.3   1.3    1.1  2020-01-01        50
# ...         ...        ...         ...   ...    ...         ...       ...
# 34851   -36.352    149.557       307.2   2.2    1.4  2020-01-30      1540
# 34852   -36.363    149.531       317.3   2.2    1.4  2020-01-30      1540
# 34853   -41.576    147.789       306.2   2.0    1.4  2020-01-30      1545
# 34854   -41.589    147.786       304.0   2.0    1.4  2020-01-30      1545
# 34855   -30.866    121.501       311.0   1.2    1.1  2020-01-30      1720
#
#       satellite instrument  confidence version  bright_t31   frp daynight
# ...

# %%
df = df[df["confidence"] >= 90]
df
# Out:
#        latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 1       -18.420    145.308       346.6   1.3    1.1  2020-01-01        50
# 8       -14.474    143.581       351.4   1.0    1.0  2020-01-01        50
# 15      -21.417    140.841       352.2   1.0    1.0  2020-01-01        50
# 17      -21.369    140.702       371.4   1.0    1.0  2020-01-01        50
# 18      -21.367    140.692       363.8   1.0    1.0  2020-01-01        50
# ...         ...        ...         ...   ...    ...         ...       ...
# 19280   -35.842    148.856       318.7   1.9    1.4  2020-01-30      1540
# 19281   -35.844    148.878       318.9   1.9    1.4  2020-01-30      1540
# 19284   -35.856    148.846       319.0   1.9    1.4  2020-01-30      1540
# 19286   -36.077    149.486       324.9   2.1    1.4  2020-01-30      1540
# 19287   -36.363    149.531       317.3   2.2    1.4  2020-01-30      1540
#
#       satellite instrument  confidence version  bright_t31   frp daynight
# ...

# %%
# Out:
# 314.6
